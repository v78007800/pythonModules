# %%
import codecs
import re
pattern = r'(?:[A-Z])+'
abbr=[]
f = codecs.open('d.txt', encoding='utf-8')
for line in f:
    abbr.extend(re.findall(pattern, repr(line)))
print(abbr)
# Out:
# ['R', 'C', 'C', 'SWIFT', 'A', 'A', 'P', 'T', 'L', 'P', 'V', 'A', 'C', 'T', 'T', 'T', 'R', 'T', 'O', 'O', 'F', 'F', 'R', 'RTI', 'A', 'A', 'I', 'A', 'A', 'C', 'L', 'P', 'R', 'T', 'T', 'T', 'T', 'T', 'V', 'N', 'P', 'P', 'P', 'C', 'E', 'P', 'E', 'P', 'E', 'V', 'N', 'V', 'A', 'D', 'C', 'C', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'F', 'F', 'P', 'T', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'S', 'N', 'B', 'F', 'F', 'C', 'I', 'F', 'F', 'C', 'N', 'A', 'I', 'L', 'C', 'C', 'ISO', 'C', 'ISO', 'D', 'C', 'C', 'ISO', 'D', 'C', 'C', 'C', 'N', 'C', 'F', 'C', 'E', 'N', 'E', 'S', 'D', 'SISCEN', 'T', 'C', 'D', 'O', 'A', 'S', 'N', 'S', 'T', 'N', 'NRO', 'CUIT', 'CUIL', 'CDI', 'F', 'P', 'F', 'R', 'N', 'F', 'T', 'M', 'M', 'M', 'C', 'D', 'O', 'P', 'L', 'C', 'N', 'R', 'R', 'CUIT', 'CUIL', 'CDI', 'T', 'D', 'A', 'N', 'T', 'D', 'N', 'D', 'F', 'O', 'T', 'T', 'M', 'E', 'T', 'M', 'E', 'E', 'I', 'T', 'M', 'M', 'A', 'I', 'T', 'P', 'D', 'E', 'BIC', 'SWIFT', 'P', 'D', 'E', 'BIC', 'SWIFT', 
# ...
